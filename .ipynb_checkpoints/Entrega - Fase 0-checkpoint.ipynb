# %% [markdown]
# # LIBRERIAS

# %%
## Librerías a usar
import networkx as nx
import pandas as pd
import matplotlib.pyplot as plt
import random
import math
from scipy.stats import norm

# %% [markdown]
# # DATOS

# %%
## Cargar la red
base=pd.read_excel("./Base-inicial.xlsx")
base
# Out:
#        Organization Name                       Headquarters Location  \
# 0                Tencent                  Shenzhen, Guangdong, China
# 1         Warburg Pincus           New York, New York, United States
# 2                Twitter    San Francisco, California, United States
# 3                Ubisoft  Montreuil-sous-bois, Ile-de-France, France
# 4                 WeWork           New York, New York, United States
# ...                  ...                                         ...
# 2206  Activation Capital                                         NaN
# 2207                Gavi                Moritzburg, Sachsen, Germany
# 2208         BF Holdings              Dudley, Dudley, United Kingdom
# 2209         GO Virginia                                         NaN
# 2210          Amit Gupta                                         NaN
#
#      Operating Status Company Type  Number of Investments  \
# 0              Active   For Profit                  693.0
# 1              Active          NaN                  433.0
# 2              Active   For Profit                   10.0
# 3              Active   For Profit                    9.0
# 4              Active   For Profit                    9.0
# ...               ...          ...                    ...
# 2206           Active          NaN                    1.0
# 2207           Active   For Profit                    NaN
# 2208           Closed   For Profit                    1.0
# 2209           Active          NaN                    2.0
# 2210           Active   For Profit                    NaN
#
#       Number of Lead Investments  Number of Diversity Investments  \
# 0                          375.0                             15.0
# 1                          286.0                             22.0
# 2                            2.0                              1.0
# 3                            NaN                              NaN
# 4                            6.0                              4.0
# ...                          ...                              ...
# 2206                         1.0                              NaN
# 2207                         NaN                              NaN
# 2208                         NaN                              NaN
# 2209                         2.0                              NaN
# 2210                         NaN                              NaN
#
#       Number of Exits  Number of Lead Investors  Number of Investors  ...  \
# 0               125.0                       1.0                  4.0  ...
# 1               131.0                       NaN                  NaN  ...
# 2                 3.0                       9.0                 37.0  ...
# 3                 1.0                       1.0                  4.0  ...
# 4                 2.0                      11.0                 24.0  ...
# ...               ...                       ...                  ...  ...
# 2206              NaN                       NaN                  NaN  ...
# 2207              NaN                       NaN                  NaN  ...
# 2208              NaN                       NaN                  NaN  ...
# 2209              NaN                       NaN                  NaN  ...
# 2210              NaN                       NaN                  NaN  ...
#
#      Total Funding Amount Currency Total Funding Amount Currency (in USD)  \
# 0                              USD                           1.257677e+10
# 1                              USD                           3.802820e+07
# 2                              USD                           4.430192e+09
# 3                              USD                           7.706506e+08
# 4                              USD                           2.159578e+10
# ...                            ...                                    ...
# 2206                           NaN                                    NaN
# 2207                           NaN                                    NaN
# 2208                           NaN                                    NaN
# 2209                           NaN                                    NaN
# 2210                           NaN                                    NaN
#
#       Number of Events SEMrush - Monthly Visits  \
# 0                 22.0                4,085,844
# 1                  NaN                   34.635
# 2                 77.0            6,026,399,205
# 3                 16.0               32,820,567
# 4                120.0                2,646,155
# ...                ...                      ...
# 2206               NaN                      NaN
# 2207               NaN                      NaN
# 2208               NaN                      NaN
# 2209               NaN                    2.495
# 2210               NaN                      NaN
#
#      SEMrush - Average Visits (6 months)  SEMrush - Visit Duration  \
# 0                              3,553,184                     600.0
# 1                              34,033.67                     392.0
# 2                       3,104,998,131.33                     942.0
# 3                          27,881,933.83                     392.0
# 4                           2,483,475.83                     280.0
# ...                                  ...                       ...
# 2206                                 NaN                       NaN
# 2207                                 NaN                       NaN
# 2208                                 NaN                       NaN
# 2209                                 NaN                       0.0
# 2210                                 NaN                       NaN
#
#      Aberdeen - IT Spend  Aberdeen - IT Spend Currency  \
# 0                    NaN                           NaN
# 1                53801.0                           USD
# 2                    NaN                           NaN
# 3                    NaN                           NaN
# 4               343977.0                           USD
# ...                  ...                           ...
# 2206                 NaN                           NaN
# 2207           4070569.0                           USD
# 2208                 NaN                           NaN
# 2209                 NaN                           NaN
# 2210                 NaN                           NaN
#
#      Aberdeen - IT Spend Currency (in USD)  \
# 0                                      NaN
# 1                                  53801.0
# 2                                      NaN
# 3                                      NaN
# 4                                 343977.0
# ...                                    ...
# 2206                                   NaN
# 2207                             4070569.0
# 2208                                   NaN
# 2209                                   NaN
# 2210                                   NaN
#
#                              Principales inversionistas
# 0      IDG Capital, Prosus & Naspers, Lippo Group, PCCW
# 1                                                   NaN
# 2     Andreessen Horowitz, Morgan Stanley, Spark Cap...
# 3     Tencent, JP Morgan Chase, Ontario Teachers' Pe...
# 4     SoftBank, JP Morgan Chase, Goldman Sachs, Insi...
# ...                                                 ...
# 2206                                                NaN
# 2207                                                NaN
# 2208                                                NaN
# 2209                                                NaN
# 2210                                                NaN
#
# [2211 rows x 34 columns]

# %%
base.dtypes
# Out:
# Organization Name                                       object
# Headquarters Location                                   object
# Operating Status                                        object
# Company Type                                            object
# Number of Investments                                  float64
# Number of Lead Investments                             float64
# Number of Diversity Investments                        float64
# Number of Exits                                        float64
# Number of Lead Investors                               float64
# Number of Investors                                    float64
# Industry Groups                                         object
# Industries                                              object
# Number of Funding Rounds                               float64
# Funding Status                                          object
# Last Funding Date                               datetime64[ns]
# Last Funding Amount                                    float64
# Last Funding Amount Currency                            object
# Last Funding Amount Currency (in USD)                  float64
# Last Funding Type                                       object
# Last Equity Funding Type                                object
# Last Equity Funding Amount                             float64
# Last Equity Funding Amount Currency                     object
# Last Equity Funding Amount Currency (in USD)           float64
# Total Funding Amount                                   float64
# Total Funding Amount Currency                           object
# Total Funding Amount Currency (in USD)                 float64
# Number of Events                                       float64
# SEMrush - Monthly Visits                                object
# SEMrush - Average Visits (6 months)                     object
# SEMrush - Visit Duration                               float64
# Aberdeen - IT Spend                                    float64
# Aberdeen - IT Spend Currency                            object
# Aberdeen - IT Spend Currency (in USD)                  float64
# Principales inversionistas                              object
# dtype: object

# %% [markdown]
# # CREACIÓN DE NODOS Y ARCOS

# %%
# Crear los nodos
nodos = base.dropna(subset=['Organization Name', 'Principales inversionistas'])
nodos
# Out:
#       Organization Name                       Headquarters Location  \
# 0               Tencent                  Shenzhen, Guangdong, China
# 2               Twitter    San Francisco, California, United States
# 3               Ubisoft  Montreuil-sous-bois, Ile-de-France, France
# 4                WeWork           New York, New York, United States
# 5            Wagestream             London, England, United Kingdom
# ...                 ...                                         ...
# 2108              Baidu                     Beijing, Beijing, China
# 2114  Backstage Capital   West Hollywood, California, United States
# 2143           Boost VC        San Mateo, California, United States
# 2147         ESL Gaming       Cologne, Nordrhein-Westfalen, Germany
# 2181           Bigpoint                   Hamburg, Hamburg, Germany
#
#      Operating Status Company Type  Number of Investments  \
# 0              Active   For Profit                  693.0
# 2              Active   For Profit                   10.0
# 3              Active   For Profit                    9.0
# 4              Active   For Profit                    9.0
# 5              Active   For Profit                    1.0
# ...               ...          ...                    ...
# 2108           Active   For Profit                  113.0
# 2114           Active          NaN                  143.0
# 2143           Active          NaN                  266.0
# 2147           Active   For Profit                    1.0
# 2181           Active   For Profit                    4.0
#
#       Number of Lead Investments  Number of Diversity Investments  \
# 0                          375.0                             15.0
# 2                            2.0                              1.0
# 3                            NaN                              NaN
# 4                            6.0                              4.0
# 5                            NaN                              NaN
# ...                          ...                              ...
# 2108                        62.0                              3.0
# 2114                        24.0                            114.0
# 2143                        25.0                             38.0
# 2147                         1.0                              NaN
# 2181                         NaN                              NaN
#
#       Number of Exits  Number of Lead Investors  Number of Investors  ...  \
# 0               125.0                       1.0                  4.0  ...
# 2                 3.0                       9.0                 37.0  ...
# 3                 1.0                       1.0                  4.0  ...
# 4                 2.0                      11.0                 24.0  ...
# 5                 NaN                       6.0                 15.0  ...
# ...               ...                       ...                  ...  ...
# 2108             27.0                       5.0                 10.0  ...
# 2114              3.0                       NaN                  1.0  ...
# 2143             29.0                       NaN                  1.0  ...
# 2147              1.0                       NaN                  1.0  ...
# 2181              2.0                       NaN                  5.0  ...
#
#      Total Funding Amount Currency Total Funding Amount Currency (in USD)  \
# 0                              USD                           1.257677e+10
# 2                              USD                           4.430192e+09
# 3                              USD                           7.706506e+08
# 4                              USD                           2.159578e+10
# 5                              USD                           2.543234e+08
# ...                            ...                                    ...
# 2108                           USD                           2.620000e+07
# 2114                           NaN                                    NaN
# 2143                           NaN                                    NaN
# 2147                           NaN                                    NaN
# 2181                           USD                           4.598708e+08
#
#       Number of Events SEMrush - Monthly Visits  \
# 0                 22.0                4,085,844
# 2                 77.0            6,026,399,205
# 3                 16.0               32,820,567
# 4                120.0                2,646,155
# 5                  NaN                   33.731
# ...                ...                      ...
# 2108              37.0              165,824,170
# 2114               1.0                   13.025
# 2143               3.0                      734
# 2147               NaN                      NaN
# 2181               NaN                  133.352
#
#      SEMrush - Average Visits (6 months)  SEMrush - Visit Duration  \
# 0                              3,553,184                    600.00
# 2                       3,104,998,131.33                    942.00
# 3                          27,881,933.83                    392.00
# 4                           2,483,475.83                    280.00
# 5                              19,865.67                    122.00
# ...                                  ...                       ...
# 2108                      135,372,669.33                    976.00
# 2114                              18.055                    546.00
# 2143                            2,610.83                     53.00
# 2147                                 NaN                       NaN
# 2181                          224,493.17                      1.75
#
#      Aberdeen - IT Spend  Aberdeen - IT Spend Currency  \
# 0                    NaN                           NaN
# 2                    NaN                           NaN
# 3                    NaN                           NaN
# 4               343977.0                           USD
# 5                    NaN                           NaN
# ...                  ...                           ...
# 2108                 NaN                           NaN
# 2114                 NaN                           NaN
# 2143                 NaN                           NaN
# 2147                 NaN                           NaN
# 2181           5223573.0                           USD
#
#      Aberdeen - IT Spend Currency (in USD)  \
# 0                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                 343977.0
# 5                                      NaN
# ...                                    ...
# 2108                                   NaN
# 2114                                   NaN
# 2143                                   NaN
# 2147                                   NaN
# 2181                             5223573.0
#
#                              Principales inversionistas
# 0      IDG Capital, Prosus & Naspers, Lippo Group, PCCW
# 2     Andreessen Horowitz, Morgan Stanley, Spark Cap...
# 3     Tencent, JP Morgan Chase, Ontario Teachers' Pe...
# 4     SoftBank, JP Morgan Chase, Goldman Sachs, Insi...
# 5     Smash Capital, Ascension, BlackRock, QED Inves...
# ...                                                 ...
# 2108  Google, IDG Capital, Threshold, ePlanet Capita...
# 2114                                   Josef Scarantino
# 2143                                           Mason Ng
# 2147                                      Omnes Capital
# 2181  TA Associates, Summit Partners, GMT Capital, P...
#
# [1195 rows x 34 columns]

# %%
nodos[nodos['Organization Name']=='Mason Ng']
# Out:
# Empty DataFrame
# Columns: [Organization Name, Headquarters Location, Operating Status, Company Type, Number of Investments, Number of Lead Investments, Number of Diversity Investments, Number of Exits, Number of Lead Investors, Number of Investors, Industry Groups, Industries, Number of Funding Rounds, Funding Status, Last Funding Date, Last Funding Amount, Last Funding Amount Currency, Last Funding Amount Currency (in USD), Last Funding Type, Last Equity Funding Type, Last Equity Funding Amount, Last Equity Funding Amount Currency, Last Equity Funding Amount Currency (in USD), Total Funding Amount, Total Funding Amount Currency, Total Funding Amount Currency (in USD), Number of Events, SEMrush - Monthly Visits, SEMrush - Average Visits (6 months), SEMrush - Visit Duration, Aberdeen - IT Spend, Aberdeen - IT Spend Currency, Aberdeen - IT Spend Currency (in USD), Principales inversionistas]
# Index: []
#
# [0 rows x 34 columns]

# %%
# Crear los arcos para estos nuevos individuos
sources = [] # lista de origenes
target = [] # lista de destinos

for i in nodos.index:
    texto = nodos["Principales inversionistas"][i]
    conexiones = texto.split(',')
    for j in range(len(conexiones)):
        # Agregar el origen
        target.append(nodos["Organization Name"][i])
        # Agregar el destino
        sources.append(conexiones[j])

# %%
# Crear el archivo de arcos

tuplas=list(zip(sources, target))

# Crear un Data Frame a partir de las tuplas
arcos = pd.DataFrame( tuplas, columns =['Source', 'Target'])
arcos
# Out:
#                             Source    Target
# 0                      IDG Capital   Tencent
# 1                 Prosus & Naspers   Tencent
# 2                      Lippo Group   Tencent
# 3                             PCCW   Tencent
# 4              Andreessen Horowitz   Twitter
# ...                            ...       ...
# 5071                 TA Associates  Bigpoint
# 5072               Summit Partners  Bigpoint
# 5073                   GMT Capital  Bigpoint
# 5074                Peacock Equity  Bigpoint
# 5075   GMT Communications Partners  Bigpoint
#
# [5076 rows x 2 columns]

# %%
nodos2 = nodos[nodos['Organization Name'].isin(arcos.Source)].drop('Principales inversionistas',axis=1)
nodos2
# Out:
#               Organization Name                       Headquarters Location  \
# 0                       Tencent                  Shenzhen, Guangdong, China
# 3                       Ubisoft  Montreuil-sous-bois, Ile-de-France, France
# 7                     Techstars            Boulder, Colorado, United States
# 12                       Zomato                     Gurgaon, Haryana, India
# 15                          SAP        Walldorf, Baden-Wurttemberg, Germany
# ...                         ...                                         ...
# 1960  Earlybird Venture Capital                     Berlin, Berlin, Germany
# 1966                  EquityZen           New York, New York, United States
# 2015              Golub Capital    San Francisco, California, United States
# 2075           ArcTern Ventures                    Toronto, Ontario, Canada
# 2143                   Boost VC        San Mateo, California, United States
#
#      Operating Status Company Type  Number of Investments  \
# 0              Active   For Profit                693.000
# 3              Active   For Profit                  9.000
# 7              Active   For Profit                  3.569
# 12             Active   For Profit                 15.000
# 15             Active   For Profit                 29.000
# ...               ...          ...                    ...
# 1960           Active   For Profit                281.000
# 1966           Active   For Profit                 37.000
# 2015           Active          NaN                 31.000
# 2075           Active          NaN                 41.000
# 2143           Active          NaN                266.000
#
#       Number of Lead Investments  Number of Diversity Investments  \
# 0                          375.0                             15.0
# 3                            NaN                              NaN
# 7                          491.0                            795.0
# 12                          13.0                              NaN
# 15                           7.0                              NaN
# ...                          ...                              ...
# 1960                       112.0                              3.0
# 1966                         2.0                              4.0
# 2015                        12.0                              3.0
# 2075                        13.0                              3.0
# 2143                        25.0                             38.0
#
#       Number of Exits  Number of Lead Investors  Number of Investors  ...  \
# 0               125.0                       1.0                  4.0  ...
# 3                 1.0                       1.0                  4.0  ...
# 7               363.0                       1.0                 11.0  ...
# 12                2.0                      12.0                 25.0  ...
# 15               14.0                       1.0                  2.0  ...
# ...               ...                       ...                  ...  ...
# 1960             44.0                       1.0                  1.0  ...
# 1966             31.0                       1.0                 16.0  ...
# 2015             14.0                       NaN                  1.0  ...
# 2075              1.0                       NaN                  1.0  ...
# 2143             29.0                       NaN                  1.0  ...
#
#      Total Funding Amount Total Funding Amount Currency  \
# 0            1.257677e+10                           USD
# 3            7.706506e+08                           USD
# 7            1.088000e+08                           USD
# 12           2.100568e+09                           USD
# 15           1.301371e+09                           USD
# ...                   ...                           ...
# 1960         1.800000e+07                           EUR
# 1966         1.130937e+07                           USD
# 2015                  NaN                           NaN
# 2075                  NaN                           NaN
# 2143                  NaN                           NaN
#
#       Total Funding Amount Currency (in USD) Number of Events  \
# 0                               1.257677e+10             22.0
# 3                               7.706506e+08             16.0
# 7                               1.088000e+08            318.0
# 12                              2.100568e+09              NaN
# 15                              1.301371e+09            239.0
# ...                                      ...              ...
# 1960                            2.098876e+07             11.0
# 1966                            1.130937e+07              2.0
# 2015                                     NaN              NaN
# 2075                                     NaN              NaN
# 2143                                     NaN              3.0
#
#      SEMrush - Monthly Visits  SEMrush - Average Visits (6 months)  \
# 0                   4,085,844                            3,553,184
# 3                  32,820,567                        27,881,933.83
# 7                     606.778                           240,410.17
# 12                 28,528,270                           22,805,302
# 15                 27,548,849                        26,208,156.17
# ...                       ...                                  ...
# 1960                    7.637                            12,045.33
# 1966                  373.848                           506,332.33
# 2015                    15.95                             10,751.5
# 2075                     3.28                                  NaN
# 2143                      734                             2,610.83
#
#      SEMrush - Visit Duration  Aberdeen - IT Spend  \
# 0                       600.0                  NaN
# 3                       392.0                  NaN
# 7                       275.0           26964318.0
# 12                      494.0                  NaN
# 15                      544.0           67473085.0
# ...                       ...                  ...
# 1960                    153.0           13241876.0
# 1966                    713.0             246443.0
# 2015                    510.0                  NaN
# 2075                     10.0                  NaN
# 2143                     53.0                  NaN
#
#      Aberdeen - IT Spend Currency Aberdeen - IT Spend Currency (in USD)
# 0                             NaN                                   NaN
# 3                             NaN                                   NaN
# 7                             USD                            26964318.0
# 12                            NaN                                   NaN
# 15                            USD                            67473085.0
# ...                           ...                                   ...
# 1960                          USD                            13241876.0
# 1966                          USD                              246443.0
# 2015                          NaN                                   NaN
# 2075                          NaN                                   NaN
# 2143                          NaN                                   NaN
#
# [152 rows x 33 columns]

# %%
arcos2 = arcos[arcos.Source.isin(nodos2['Organization Name'])]
arcos2
# Out:
#                       Source       Target
# 9                    Tencent      Ubisoft
# 13                  SoftBank       WeWork
# 41            Galaxy Digital        Terra
# 46    Digital Currency Group         Wyre
# 51                     Apple       Zomato
# ...                      ...          ...
# 5030                 Tencent   DST Global
# 5043            500 Startups  Golden Gate
# 5050                  Google          AOL
# 5061             BC Partners   Altice USA
# 5063                  Google        Baidu
#
# [377 rows x 2 columns]

# %%
nodos2 = nodos2.set_index('Organization Name')

# %%
# Construir red
G=nx.DiGraph()
# Nodos
# Agregar los nodos por su identificador
G.add_nodes_from(nodos2.index)
# Agregar los atributos de los nodos
# Primero recorrer los nodos que se agregaron a la red
for nodo in G.nodes:
    # En cada nodo recorremos los atributos de los nodos
    for atr in nodos2:
        # Agregar cada atributo al nodo
        G.nodes[nodo][atr]=nodos2[atr][nodo]
# Arcos
# Agregar los arcos
G.add_edges_from([tuple(x) for x in arcos2[['Source','Target']].to_numpy()])

# %%
# Lienzo de la gráfica
fig=plt.figure(figsize=(15,15))
# Después se genera el gráfico
nx.draw_kamada_kawai(G, node_size=50, node_color='lightgreen', edge_color='lightgray')
# Por último se muestra la gráfica
plt.show()

# %%
nodos2.to_csv('nodos.csv')

# %%
arcos2.to_csv('arcos.csv')

# %% [markdown]
# # Medidas de centralidad y prestigio
